# %%
"""
Topic:        Project 2
Subject:      Carbon Emissions
Date:         xx/xx/xxxx
Name:         Leo Knauth
Worked with:  --


""";

# %%
import pandas as pd
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import re
import time
import random
import sys
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os

# %%
url_carbon_per_capita = 'https://www.gapminder.org/data/'

# %%
# does not produce the desired output
# tables = pd.read_html(url_carbon_per_capita)

# %%
# tables;

# %%
response = requests.get(url_carbon_per_capita)

# %%
response.status_code
# Out:
# 200

# %%
page = response.text

# %%
page;

# %%
# soup = BeautifulSoup(page, "lxml")

# %%
# table = soup.find_all(class_="contentReport")

# %%
# cbpReport_rgx = re.compile('class="dxgvControl_GridDefaultTheme"')

# %%
# report_string = soup.find_all(text = cbpReport_rgx)
# for item in report_string:
#     print(item)

# %%
# table

# %%
# chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
# os.environ["webdriver.chrome.driver"] = chromedriver
# driver = webdriver.Chrome(chromedriver)

# %%
# driver.get(url_carbon_per_capita)

# %%
# co2_table_selector = '//span[contains(text(), "CO2 emissions")]'

# %%
# time.sleep(5) 
# print(driver.find_element_by_xpath(co2_table_selector).text)

# %%
# search_field = driver.find_element_by_id("indicators-table_filter")

# %%
# search_field.send_keys('CO2 emissions')

# %%
# search_field = driver.find_element_by_xpath("//div[@id = 'indicators-table_filter']/input")

# %%
# search_field.send_keys('CO2 emissions')

# %%
# search_res = driver.find_element_by_xpath("//a[@class = 'openRow']/input")

# %%
url_data = 'https://docs.google.com/spreadsheets/d/1RjqGm7RG82GGVf7E4RXPPwFF7O1So6T0SFx2fVfcUJA/pub'

# %%
# soup = BeautifulSoup(requests.get(url_data).text, 'lxml')

# %%
# print(soup.prettify())

# %%
tables = pd.read_html(url_data, header=0)

# %%
tables = pd.read_html(url_data)

# %%
df = tables[0]

# %%
tables[0]
# Out:
#      Unnamed: 0                Unnamed: 1  Unnamed: 2   Unnamed: 3  \
# 0           1.0            CO2 per capita         NaN  1751.000000
# 1           NaN                       NaN         NaN          NaN
# 2           2.0                  Abkhazia         NaN          NaN
# 3           3.0               Afghanistan         NaN          NaN
# 4           4.0     Akrotiri and Dhekelia         NaN          NaN
# 5           5.0                   Albania         NaN          NaN
# 6           6.0                   Algeria         NaN          NaN
# 7           7.0            American Samoa         NaN          NaN
# 8           8.0                   Andorra         NaN          NaN
# 9           9.0                    Angola         NaN          NaN
# 10         10.0                  Anguilla         NaN          NaN
# 11         11.0       Antigua and Barbuda         NaN          NaN
# 12         12.0                 Argentina         NaN          NaN
# ...

# %%
df.rename(columns={'coutry': 'country'}, inplace=True)

# %%
# df.drop('1', 1, inplace = True)

# %%
df
# Out:
#      Unnamed: 0                Unnamed: 1  Unnamed: 2   Unnamed: 3  \
# 0           1.0            CO2 per capita         NaN  1751.000000
# 1           NaN                       NaN         NaN          NaN
# 2           2.0                  Abkhazia         NaN          NaN
# 3           3.0               Afghanistan         NaN          NaN
# 4           4.0     Akrotiri and Dhekelia         NaN          NaN
# 5           5.0                   Albania         NaN          NaN
# 6           6.0                   Algeria         NaN          NaN
# 7           7.0            American Samoa         NaN          NaN
# 8           8.0                   Andorra         NaN          NaN
# 9           9.0                    Angola         NaN          NaN
# 10         10.0                  Anguilla         NaN          NaN
# 11         11.0       Antigua and Barbuda         NaN          NaN
# 12         12.0                 Argentina         NaN          NaN
# ...

# %%
df.drop(df.index[[0]], inplace = True)

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#      Unnamed: 0                Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0           NaN                       NaN         NaN         NaN         NaN
# 1           2.0                  Abkhazia         NaN         NaN         NaN
# 2           3.0               Afghanistan         NaN         NaN         NaN
# 3           4.0     Akrotiri and Dhekelia         NaN         NaN         NaN
# 4           5.0                   Albania         NaN         NaN         NaN
# 5           6.0                   Algeria         NaN         NaN         NaN
# 6           7.0            American Samoa         NaN         NaN         NaN
# 7           8.0                   Andorra         NaN         NaN         NaN
# 8           9.0                    Angola         NaN         NaN         NaN
# 9          10.0                  Anguilla         NaN         NaN         NaN
# 10         11.0       Antigua and Barbuda         NaN         NaN         NaN
# ...

# %%
df.to_pickle('co2_per_capita.pkl')

# %%
url_gdp = 'https://docs.google.com/spreadsheets/d/1PybxH399kK6OjJI4T2M33UsLqgutwj3SuYbk7Yt6sxE/pub'

# %%
tables_gdp = pd.read_html(url_gdp, header=0)

# %%
df_gdp = tables_gdp[0]

# %%
df_gdp.rename(columns={'GDP per capita': 'country'}, inplace=True)

# %%
# df_gdp.head()

# %%
# df_gdp.drop('1', 1, inplace = True)

# %%
# df_gdp.head()

# %%
# df_gdp.drop('Unnamed: 2', 1, inplace = True)

# %%
df_gdp
# Out:
#      Unnamed: 0                Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0           1.0            GDP per capita         NaN      1800.0      1801.0
# 1           NaN                       NaN         NaN         NaN         NaN
# 2           2.0                  Abkhazia         NaN         NaN         NaN
# 3           3.0               Afghanistan         NaN       603.0       603.0
# 4           4.0     Akrotiri and Dhekelia         NaN         NaN         NaN
# 5           5.0                   Albania         NaN       667.0       667.0
# 6           6.0                   Algeria         NaN       716.0       716.0
# 7           7.0            American Samoa         NaN         NaN         NaN
# 8           8.0                   Andorra         NaN      1197.0      1199.0
# 9           9.0                    Angola         NaN       618.0       620.0
# 10         10.0                  Anguilla         NaN         NaN         NaN
# ...

# %%
df_gdp.drop(df.index[[0]], inplace = True)

# %%
df_gdp.reset_index(drop = True, inplace = True)

# %%
df_gdp.head()
# Out:
#    Unnamed: 0             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN                    NaN         NaN         NaN         NaN
# 1         2.0               Abkhazia         NaN         NaN         NaN
# 2         3.0            Afghanistan         NaN       603.0       603.0
# 3         4.0  Akrotiri and Dhekelia         NaN         NaN         NaN
# 4         5.0                Albania         NaN       667.0       667.0
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2       603.0       603.0       603.0       603.0       603.0  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4       668.0       668.0       668.0       668.0       668.0  ...
#
#    Unnamed: 209  Unnamed: 210  Unnamed: 211  Unnamed: 212  Unnamed: 213  \
# ...

# %%
df_gdp.to_pickle('gdp_per_capita.pkl')

# %%
url_urban = 'https://docs.google.com/spreadsheets/d/1JCdQQDn2vjmjbt1hTq5wE4Adf2xIuO6i4bY1bNtGDYQ/pub'

# %%
tables_urban = pd.read_html(url_urban, header=0)

# %%
df_urban = tables_urban[0]

# %%
df_urban.head()
# Out:
#    Unnamed: 0                     Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0           1  Urban population (% of total)      1960.0    1961.000
# 1           2                       Abkhazia         NaN         NaN
# 2           3                    Afghanistan         8.0       8.265
# 3           4          Akrotiri and Dhekelia         NaN         NaN
# 4           5                        Albania        30.7      30.810
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0    1962.000    1963.000    1964.000    1965.000   1966.0000   1967.0000
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2       8.537       8.809       9.081       9.353      9.6886     10.0242
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4      30.915      31.020      31.125      31.230     31.3320     31.4340
#
#    ...  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  Unnamed: 48  \
# ...

# %%
df_urban.to_pickle('urban.pkl')
