# %%
"""
Topic:        Project 2
Subject:      Carbon Emissions
Date:         xx/xx/xxxx
Name:         Leo Knauth
Worked with:  --


""";

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.tsa.stattools as ts
from statsmodels.tsa.stattools import adfuller


import warnings
warnings.filterwarnings('ignore')

import itertools

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

from pandas.plotting import autocorrelation_plot

import re

import sys
import os

from functools import reduce

# %%
df_gdp = pd.read_pickle("gdp_per_capita.pkl")

# %%
df_gdp.head()
# Out:
#    Unnamed: 0             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN                    NaN         NaN         NaN         NaN
# 1         2.0               Abkhazia         NaN         NaN         NaN
# 2         3.0            Afghanistan         NaN       603.0       603.0
# 3         4.0  Akrotiri and Dhekelia         NaN         NaN         NaN
# 4         5.0                Albania         NaN       667.0       667.0
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2       603.0       603.0       603.0       603.0       603.0  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4       668.0       668.0       668.0       668.0       668.0  ...
#
#    Unnamed: 209  Unnamed: 210  Unnamed: 211  Unnamed: 212  Unnamed: 213  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2        1173.0        1298.0        1311.0        1548.0        1637.0
# 3           NaN           NaN           NaN           NaN           NaN
# 4        7476.0        7977.0        8644.0        8994.0        9374.0
#
#    Unnamed: 214  Unnamed: 215  Unnamed: 216  Unnamed: 217  Unnamed: 218
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2        1695.0        1893.0        1884.0        1877.0        1925.0
# 3           NaN           NaN           NaN           NaN           NaN
# 4        9640.0        9811.0        9961.0       10160.0       10620.0
#
# [5 rows x 219 columns]

# %%
df_co2 = pd.read_pickle('co2_per_capita.pkl')

# %%
df_co2.head()
# Out:
#    Unnamed: 0             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN                    NaN         NaN         NaN         NaN
# 1         2.0               Abkhazia         NaN         NaN         NaN
# 2         3.0            Afghanistan         NaN         NaN         NaN
# 3         4.0  Akrotiri and Dhekelia         NaN         NaN         NaN
# 4         5.0                Albania         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN         NaN         NaN  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 246  Unnamed: 247  Unnamed: 248  Unnamed: 249  Unnamed: 250  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2      0.022704      0.027472      0.036780       0.04709      0.068312
# 3           NaN           NaN           NaN           NaN           NaN
# 4      1.382066      1.332966      1.353789       1.22431      1.279420
#
#    Unnamed: 251  Unnamed: 252  Unnamed: 253  Unnamed: 254  Unnamed: 255
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2      0.131602      0.213325      0.262174           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4      1.297753      1.215055      1.336544           NaN           NaN
#
# [5 rows x 256 columns]

# %%
select_years = list(map( lambda x : str(x), range(1962, 2013)))
select_years;

# %%
df_gdp_years = df_gdp[['country'] + select_years]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-3799f47b6dbc> in <module>
# ----> 1 df_gdp_years = df_gdp[['country'] + select_years]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['country', '1962', '1963', '1964', '1965', '1966', '1967', '1968',\n       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',\n       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',\n       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',\n       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',\n       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012'],\n      dtype='object')] are in the [columns]"
